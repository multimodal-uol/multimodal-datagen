# %%
import subprocess
movie = 'https://www.youtube-nocookie.com/embed/WAlslN90CWw?wmode=opaque&feature=oembed'
cmd = '/opt/anaconda3/bin/videodesc https://www.youtube-nocookie.com/embed/WAlslN90CWw?wmode=opaque\&feature=oembed 1'
movie1='https://www.youtube-nocookie.com/embed/WAlslN90CWw?wmode=opaque\&feature=oembed'


cmd = ('/usr/bin/videodesc ' + movie1 + ' '+ '1') 

a= subprocess.run(['/opt/anaconda3/bin/python3.7', 
                   'VideoDescription.py', 
                   'https://www.youtube-nocookie.com/embed/WAlslN90CWw?wmode=opaque\\&feature=oembed', 
                   '1'], capture_output=True)
print(a.stdout)
# Out:
# b' card paper illustration vector text bill retro design picture frame desktop art greeting vintage love graphic invitation chalk out typography page note\n'

# %%
import subprocess 
out = subprocess.check_output(["ls", "-l"], encoding="utf-8")

# %%
import subprocess
subprocess.run(["export LD_LIBRARY_PATH=/opt/splunk/lib/:$LD_LIBRARY_PATH"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-b8e5beddadb9> in <module>
#       1 import subprocess
# ----> 2 subprocess.run(["export LD_LIBRARY_PATH=/opt/splunk/lib/:$LD_LIBRARY_PATH"])
#
# /opt/anaconda3/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486         kwargs['stderr'] = PIPE
#     487
# --> 488     with Popen(*popenargs, **kwargs) as process:
#     489         try:
#     490             stdout, stderr = process.communicate(input, timeout=timeout)
#
# /opt/anaconda3/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     798                                 c2pread, c2pwrite,
# ...

# %%
import subprocess

p = subprocess.run("ls -l", capture_output=True, shell=True, encoding="utf8")
print(p.stdout)
# Out:
# total 2740
# -rwxrwxrwx.  1 root root       0 Oct  6 17:05 20200516-143447.json
# -rwxrwxrwx.  1 root root       0 Oct  6 17:05 20200516-143448.json
# -rwxrwxrwx.  1 root root       0 Oct  6 17:05 20200516-143451.json
# -rwxrwxrwx.  1 root root       0 Oct  6 17:05 20200516-143510.json
# -rwxrwxrwx.  1 root root       0 Oct  6 17:05 20200516-143511.json
# -rwxrwxrwx.  1 root root 1439755 Oct  6 17:05 20200516-143514.json
# drwxrwxrwx.  3 root root      44 Oct  6 17:05 apiclient
# -rwxrwxrwx.  1 root root    3983 Oct  6 17:05 app.py
# -rwxrwxrwx.  1 root root    3484 Oct  6 17:05 app.pyc
# drwxr-xr-x.  3 root root    4096 Oct 20 16:04 attr
# drwxr-xr-x.  2 root root     121 Oct 20 16:04 attrs-20.2.0.dist-info
# drwxrwxrwx.  9 root root    4096 Oct  6 17:05 beautifulsoup4-4.9.0
# -rwxrwxrwx.  1 root root  368809 Oct  6 17:05 beautifulsoup4-4.9.0.tar.gz
# drwxrwxrwx.  4 root root    4096 Oct  6 17:05 billiard
# -rwxrwxrwx.  1 root root  155090 Oct  6 17:05 billiard-3.6.3.0.tar.gz
# ...
